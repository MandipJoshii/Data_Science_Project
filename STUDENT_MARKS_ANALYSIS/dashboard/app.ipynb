# %%
pip install dash plotly
# Out:
# Requirement already satisfied: dash in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.4.0)
# Requirement already satisfied: plotly in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (6.5.2)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (3.1.5)
# Requirement already satisfied: importlib-metadata in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (8.7.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\asus\appdata\roaming\python\python314\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from dash) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.0.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from plotly) (2.15.0)
# Requirement already satisfied: packaging in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from plotly) (25.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\roaming\python\python314\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests->dash) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dash import Dash, html, dcc, Input, Output
import pandas as pd
import plotly.express as px

app = Dash(__name__)

df = pd.read_csv("../student-mat.csv", delimiter=";")

app.layout = html.Div([
    html.H1("Student Performance Dashboard"),

    html.Label("Select a feature to explore:"),
    dcc.Dropdown(
        id="feature-dropdown",
        options=[
            {"label": "Study Time", "value": "studytime"},
            {"label": "Absences",   "value": "absences"},
            {"label": "G1",         "value": "G1"},
            {"label": "G2",         "value": "G2"},
        ],
        value="studytime"
    ),

    dcc.Graph(id="histogram-graph")
])

@app.callback(
    Output("histogram-graph", "figure"),
    Input("feature-dropdown", "value")
)
def update_histogram(selected_feature):
    fig = px.histogram(df, x=selected_feature, title=f"Distribution of {selected_feature}")
    return fig

app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2026-03-04 13:32:36,180] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#            ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\dash.py", line 1600, in dispatch
#     response_data = ctx.run(partial_func)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 720, in add_context
#     raise err
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\asus\AppData\Local\Temp\ipykernel_18688\431837507.py", line 6, in update_histogram
#     fig = px.histogram(df, x=selected_feature, title=f"Distribution of {selected_feature}")
#                        ^^
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_jupyter.py", line 529, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#            ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\dash.py", line 1600, in dispatch
#     response_data = ctx.run(partial_func)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 720, in add_context
#     raise err
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\asus\AppData\Local\Temp\ipykernel_18688\431837507.py", line 6, in update_histogram
#     fig = px.histogram(df, x=selected_feature, title=f"Distribution of {selected_feature}")
#                        ^^
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_jupyter.py", line 529, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\werkzeug\serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\werkzeug\serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_jupyter.py", line 529, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# [2026-03-04 13:32:41,876] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#            ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\dash.py", line 1600, in dispatch
#     response_data = ctx.run(partial_func)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 720, in add_context
#     raise err
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\asus\AppData\Local\Temp\ipykernel_18688\431837507.py", line 6, in update_histogram
#     fig = px.histogram(df, x=selected_feature, title=f"Distribution of {selected_feature}")
#                        ^^
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_jupyter.py", line 529, in _wrap_errors
#     ipytb = FormattedTB(
#         tb_offset=skip,
#     ...<3 lines>...
#         ostream=ostream,
#     )
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
# Error on request:
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_get_app.py", line 17, in wrap
#     return ctx.run(func, self, *args, **kwargs)
#            ~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\dash.py", line 1600, in dispatch
#     response_data = ctx.run(partial_func)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 720, in add_context
#     raise err
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 711, in add_context
#     output_value = _invoke_callback(func, *func_args, **func_kwargs)  # type: ignore[reportArgumentType]
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_callback.py", line 58, in _invoke_callback
#     return func(*args, **kwargs)  # %% callback invoked %%
#   File "C:\Users\asus\AppData\Local\Temp\ipykernel_18688\431837507.py", line 6, in update_histogram
#     fig = px.histogram(df, x=selected_feature, title=f"Distribution of {selected_feature}")
#                        ^^
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 809, in handle_user_exception
#     return self.ensure_sync(handler)(e)  # type: ignore[no-any-return]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_jupyter.py", line 529, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\werkzeug\serving.py", line 370, in run_wsgi
#     execute(self.server.app)
#     ~~~~~~~^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\werkzeug\serving.py", line 331, in execute
#     application_iter = app(environ, start_response)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1536, in __call__
#     return self.wsgi_app(environ, start_response)
#            ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 1514, in wsgi_app
#     response = self.handle_exception(e)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\flask\app.py", line 860, in handle_exception
#     server_error = self.ensure_sync(handler)(server_error)
#   File "c:\Users\asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\dash\_jupyter.py", line 529, in _wrap_errors
#     ipytb = FormattedTB(
#
# TypeError: FormattedTB.__init__() got an unexpected keyword argument 'color_scheme'
