# %% [markdown]
# # 1. what factors are affecting G3

# %%
"""what factors are affecting G3 will help us know which features of input 
are actually useful and which arent so we can apply dimentionaly reduction to it"""

# %%
"""next i will do is finding linear or non linearness in my dataset 
if:
linear is found = apply linear regression
else other form of regressions/algorithms

and thus model will be selected like that way

we will also work in outliners and extreme or reasonable values


"""

# %%
import matplotlib as plt

plt.__version__
# Out:
# '3.10.7'

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("../../student-mat.csv",delimiter=';')
x_axis = df['absences'].sample(10)
y_axis = df['G3'].sample(10)
df.head()

plt.plot(x_axis,y_axis,color='red',linewidth='2',marker='o',markersize='10', mfc='yellow',mec='yellow')

plt.show()

# %%
df['G3'].max()
df['absences'].max()
# Out:
# np.int64(75)

# %% [markdown]
# ### a bit advance way to reuse the same properties in different plots could be used also in histograph, scattergraph etc

# %%
line_style = dict(color='red',linewidth='2',marker='o',markersize='10', mfc='yellow',mec='yellow')
x = df['absences'].head()
y = df['G3'].head()
plt.plot(x,y, **line_style)
