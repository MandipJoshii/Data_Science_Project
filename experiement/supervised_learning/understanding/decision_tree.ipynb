# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
student = pd.read_csv('../../../student-mat.csv',delimiter=';')

df = pd.DataFrame(student)

# %%
X = df[['G1','G2','Medu','studytime']]
y = df['G3']

# %%
X_train,x_test,Y_train,y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=42)

# %%
model = DecisionTreeRegressor(max_depth=5,random_state=42)

model.fit(X_train,Y_train)

predict = model.predict(x_test)

print(predict)
# Out:
# [ 8.75       11.85294118  5.5         8.68421053  8.68421053 12.75
#  19.          6.          6.88888889 13.4        15.29166667  6.
#  14.2        11.85294118 14.2         6.88888889  6.         10.82142857
#  15.29166667  0.         14.2        16.         15.29166667  5.5
#   0.         18.2        10.82142857  9.4        17.66666667 10.82142857
#   8.68421053  6.88888889 15.29166667 13.4         6.          1.375
#   0.         15.29166667 11.85294118  8.68421053  6.5        10.82142857
#  14.2         8.68421053 15.29166667 10.6        11.85294118 14.2
#  13.         15.29166667 12.75       15.29166667 10.82142857  8.68421053
#   1.375      12.75       10.6         4.         15.29166667 16.
#  13.          8.68421053  8.75        1.375       6.         17.66666667
#   8.68421053  9.4         9.4        15.29166667  6.88888889  9.4
#  13.4        18.2        10.82142857  6.5         8.68421053 14.2
#   1.375     ]

# %%
#metrics

mae = mean_absolute_error(y_test,predict)
mse = mean_squared_error(y_test,predict)
r2 = r2_score(y_test,predict)

print("mae:",mae)
print("mse:",mse)
print("r2_score:",r2)
# Out:
# mae: 1.0659703055106118
# mse: 2.6534612786925234
# r2_score: 0.8705947250936139
